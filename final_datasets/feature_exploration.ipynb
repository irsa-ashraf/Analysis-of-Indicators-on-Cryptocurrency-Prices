# %%
import pandas as pd
import numpy as np

# %%
bitcoin = pd.read_csv("../models/bitcoin_train.csv")
dogecoin = pd.read_csv("../models/dogecoin_train.csv")

# %%
bitcoin.dtypes
# Out:
# Unnamed: 0                   int64
# Date                        object
# Open                       float64
# High                       float64
# Low                        float64
#                             ...
# Open_SP500                 float64
# Daily_Change_SP500         float64
# Daily_Change_Perc_SP500    float64
# Increased_SP500              int64
# label                      float64
# Length: 62, dtype: object

# %%
feature_list = ['MACD','PROC_3', 'PROC_5', 'PROC_10', 'wpr', 'goog_trend_score', 'compound_weighted',\
                'neg_weighted', 'pos_weighted', 'count_avg7', 'count_daily_diff', 'count_weekly_diff',\
                'replies_count_avg7', 'replies_count_daily_diff', 'replies_count_weekly_diff', 'retweets_count_avg7',\
                'retweets_count_daily_diff', 'retweets_count_weekly_diff', 'likes_count_avg7',\
                'likes_count_daily_diff', 'likes_count_weekly_diff', 'compound_weighted_avg7', \
                'compound_weighted_daily_diff', 'compound_weighted_weekly_diff', 'pos_weighted_avg7', \
                'pos_weighted_daily_diff', 'pos_weighted_weekly_diff', 'neg_weighted_avg7', \
                'neg_weighted_daily_diff','neg_weighted_weekly_diff','Daily_Change_Perc', 'Weekly_Change_Perc',\
                'Daily_Change_Perc_Gold', 'Daily_Change_Perc_SP500', 'RSI']

# %%
financial_features = ['MACD','PROC_3', 'PROC_5', 'PROC_10', 'wpr', 'RSI', 'Daily_Change_Perc',\
                      'Daily_Change_Perc_Gold', 'Daily_Change_Perc_SP500']
social_features = ['goog_trend_score', 'compound_weighted',\
                'neg_weighted', 'pos_weighted', 'count_avg7', 'count_daily_diff', 'count_weekly_diff',\
                'replies_count_avg7', 'replies_count_daily_diff', 'replies_count_weekly_diff', 'retweets_count_avg7',\
                'retweets_count_daily_diff', 'retweets_count_weekly_diff', 'likes_count_avg7',\
                'likes_count_daily_diff', 'likes_count_weekly_diff', 'compound_weighted_avg7', \
                'compound_weighted_daily_diff', 'compound_weighted_weekly_diff', 'pos_weighted_avg7', \
                'pos_weighted_daily_diff', 'pos_weighted_weekly_diff', 'neg_weighted_avg7', \
                'neg_weighted_daily_diff','neg_weighted_weekly_diff',]

# %%
def get_corr_matrices(df, features, y):

    feature_corr = df[features].corr()
    columns = feature_corr.columns.values.tolist()
    
    def color_corr(x):
        colors = []
        for col in columns:
            if col == x.name:
                colors.append("background: gray")
            elif x[col] > 0.7 or x[col] < -0.7:
                colors.append("background: red")
            elif x[col] > 0.5 or x[col] < -0.5:
                colors.append("background: yellow")
            else: 
                colors.append("")
        return colors

    feature_corr = feature_corr.style.apply(color_corr, axis=1)
    label_corr_list = []

    for feature in features:
        corr = df[feature].corr(df[y])
        label_corr_list.append([feature, np.abs(corr)])
    
    label_corr_list.sort(reverse=True, key= lambda x : x[1])
    label_corr = pd.DataFrame(label_corr_list, columns = ['Feature', 'Corr'])

    return feature_corr, label_corr

# %%
bit_feat_corr, bit_label_corr = get_corr_matrices(bitcoin, financial_features, 'label')

# %%
bit_feat_corr
# Out:
# <style  type="text/css" >
# #T_fdf99_row0_col0,#T_fdf99_row1_col1,#T_fdf99_row2_col2,#T_fdf99_row3_col3,#T_fdf99_row4_col4,#T_fdf99_row5_col5,#T_fdf99_row6_col6,#T_fdf99_row7_col7,#T_fdf99_row8_col8{
#             background:  gray;
#         }#T_fdf99_row0_col5,#T_fdf99_row1_col3,#T_fdf99_row1_col4,#T_fdf99_row1_col5,#T_fdf99_row1_col6,#T_fdf99_row2_col4,#T_fdf99_row2_col5,#T_fdf99_row3_col1,#T_fdf99_row3_col4,#T_fdf99_row4_col1,#T_fdf99_row4_col2,#T_fdf99_row4_col3,#T_fdf99_row4_col6,#T_fdf99_row5_col0,#T_fdf99_row5_col1,#T_fdf99_row5_col2,#T_fdf99_row6_col1,#T_fdf99_row6_col4{
#             background:  yellow;
#         }#T_fdf99_row1_col2,#T_fdf99_row2_col1,#T_fdf99_row2_col3,#T_fdf99_row3_col2,#T_fdf99_row3_col5,#T_fdf99_row4_col5,#T_fdf99_row5_col3,#T_fdf99_row5_col4{
#             background:  red;
#         }</style><table id="T_fdf99_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MACD</th>        <th class="col_heading level0 col1" >PROC_3</th>        <th class="col_heading level0 col2" >PROC_5</th>        <th class="col_heading level0 col3" >PROC_10</th>        <th class="col_heading level0 col4" >wpr</th>        <th class="col_heading level0 col5" >RSI</th>        <th class="col_heading level0 col6" >Daily_Change_Perc</th>        <th class="col_heading level0 col7" >Daily_Change_Perc_Gold</th>        <th class="col_heading level0 col8" >Daily_Change_Perc_SP500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdf99_level0_row0" class="row_heading level0 row0" >MACD</th>
#                         <td id="T_fdf99_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_fdf99_row0_col1" class="data row0 col1" >0.192118</td>
#                         <td id="T_fdf99_row0_col2" class="data row0 col2" >0.262594</td>
#                         <td id="T_fdf99_row0_col3" class="data row0 col3" >0.475475</td>
#                         <td id="T_fdf99_row0_col4" class="data row0 col4" >0.266930</td>
#                         <td id="T_fdf99_row0_col5" class="data row0 col5" >0.539179</td>
#                         <td id="T_fdf99_row0_col6" class="data row0 col6" >0.071249</td>
#                         <td id="T_fdf99_row0_col7" class="data row0 col7" >-0.035243</td>
#                         <td id="T_fdf99_row0_col8" class="data row0 col8" >0.036954</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row1" class="row_heading level0 row1" >PROC_3</th>
#                         <td id="T_fdf99_row1_col0" class="data row1 col0" >0.192118</td>
#                         <td id="T_fdf99_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_fdf99_row1_col2" class="data row1 col2" >0.818099</td>
#                         <td id="T_fdf99_row1_col3" class="data row1 col3" >0.585475</td>
#                         <td id="T_fdf99_row1_col4" class="data row1 col4" >0.627979</td>
#                         <td id="T_fdf99_row1_col5" class="data row1 col5" >0.510222</td>
#                         <td id="T_fdf99_row1_col6" class="data row1 col6" >0.590778</td>
#                         <td id="T_fdf99_row1_col7" class="data row1 col7" >0.052800</td>
#                         <td id="T_fdf99_row1_col8" class="data row1 col8" >0.058325</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row2" class="row_heading level0 row2" >PROC_5</th>
#                         <td id="T_fdf99_row2_col0" class="data row2 col0" >0.262594</td>
#                         <td id="T_fdf99_row2_col1" class="data row2 col1" >0.818099</td>
#                         <td id="T_fdf99_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_fdf99_row2_col3" class="data row2 col3" >0.733150</td>
#                         <td id="T_fdf99_row2_col4" class="data row2 col4" >0.677458</td>
#                         <td id="T_fdf99_row2_col5" class="data row2 col5" >0.607987</td>
#                         <td id="T_fdf99_row2_col6" class="data row2 col6" >0.485714</td>
#                         <td id="T_fdf99_row2_col7" class="data row2 col7" >0.049506</td>
#                         <td id="T_fdf99_row2_col8" class="data row2 col8" >0.079375</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row3" class="row_heading level0 row3" >PROC_10</th>
#                         <td id="T_fdf99_row3_col0" class="data row3 col0" >0.475475</td>
#                         <td id="T_fdf99_row3_col1" class="data row3 col1" >0.585475</td>
#                         <td id="T_fdf99_row3_col2" class="data row3 col2" >0.733150</td>
#                         <td id="T_fdf99_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_fdf99_row3_col4" class="data row3 col4" >0.691064</td>
#                         <td id="T_fdf99_row3_col5" class="data row3 col5" >0.744366</td>
#                         <td id="T_fdf99_row3_col6" class="data row3 col6" >0.342134</td>
#                         <td id="T_fdf99_row3_col7" class="data row3 col7" >0.036876</td>
#                         <td id="T_fdf99_row3_col8" class="data row3 col8" >0.092178</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row4" class="row_heading level0 row4" >wpr</th>
#                         <td id="T_fdf99_row4_col0" class="data row4 col0" >0.266930</td>
#                         <td id="T_fdf99_row4_col1" class="data row4 col1" >0.627979</td>
#                         <td id="T_fdf99_row4_col2" class="data row4 col2" >0.677458</td>
#                         <td id="T_fdf99_row4_col3" class="data row4 col3" >0.691064</td>
#                         <td id="T_fdf99_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_fdf99_row4_col5" class="data row4 col5" >0.706751</td>
#                         <td id="T_fdf99_row4_col6" class="data row4 col6" >0.544168</td>
#                         <td id="T_fdf99_row4_col7" class="data row4 col7" >0.032950</td>
#                         <td id="T_fdf99_row4_col8" class="data row4 col8" >0.140663</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row5" class="row_heading level0 row5" >RSI</th>
#                         <td id="T_fdf99_row5_col0" class="data row5 col0" >0.539179</td>
#                         <td id="T_fdf99_row5_col1" class="data row5 col1" >0.510222</td>
#                         <td id="T_fdf99_row5_col2" class="data row5 col2" >0.607987</td>
#                         <td id="T_fdf99_row5_col3" class="data row5 col3" >0.744366</td>
#                         <td id="T_fdf99_row5_col4" class="data row5 col4" >0.706751</td>
#                         <td id="T_fdf99_row5_col5" class="data row5 col5" >1.000000</td>
#                         <td id="T_fdf99_row5_col6" class="data row5 col6" >0.313829</td>
#                         <td id="T_fdf99_row5_col7" class="data row5 col7" >0.005440</td>
#                         <td id="T_fdf99_row5_col8" class="data row5 col8" >0.060114</td>
#             </tr>
#             <tr>
#                         <th id="T_fdf99_level0_row6" class="row_heading level0 row6" >Daily_Change_Perc</th>
#                         <td id="T_fdf99_row6_col0" class="data row6 col0" >0.071249</td>
#                         <td id="T_fdf99_row6_col1" class="data row6 col1" >0.590778</td>
#                         <td id="T_fdf99_row6_col2" class="data row6 col2" >0.485714</td>
#                         <td id="T_fdf99_row6_col3" class="data row6 col3" >0.342134</td>
#                         <td id="T_fdf99_row6_col4" class="data row6 col4" >0.544168</td>
#                         <td id="T_fdf99_row6_col5" class="data row6 col5" >0.313829</td>
#                         <td id="T_fdf99_row6_col6" class="data row6 col6" >1.000000</td>
#                         <td id="T_fdf99_row6_col7" class="data row6 col7" >0.074008</td>
#                         <td id="T_fdf99_row6_col8" class="data row6 col8" >0.154932</td>

# %%
bit_label_corr
# Out:
#                    Feature      Corr
# 0                      RSI  0.076950
# 1  Daily_Change_Perc_SP500  0.046922
# 2                      wpr  0.030434
# 3   Daily_Change_Perc_Gold  0.027668
# 4                   PROC_3  0.014206
# 5                     MACD  0.011540
# 6        Daily_Change_Perc  0.009212
# 7                  PROC_10  0.007456
# 8                   PROC_5  0.000029

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(bitcoin[financial_features], bitcoin['label'])
importances = rf.feature_importances_.tolist()

# %%
importances_df = pd.DataFrame(list(zip(financial_features, importances)), columns=["feature", "importance"])

# %%
importances_df.sort_values(by=['importance'], ascending=False)
# Out:
#                    feature  importance
# 0                     MACD    0.119547
# 4                      wpr    0.115768
# 5                      RSI    0.113797
# 8  Daily_Change_Perc_SP500    0.113767
# 3                  PROC_10    0.113371
# 7   Daily_Change_Perc_Gold    0.110090
# 1                   PROC_3    0.107322
# 2                   PROC_5    0.105995
# 6        Daily_Change_Perc    0.100344

# %%
social_feat_corr, social_label_corr = get_corr_matrices(bitcoin, social_features, 'label')

# %%
social_feat_corr
# Out:
# <style  type="text/css" >
# #T_1e959_row0_col0,#T_1e959_row1_col1,#T_1e959_row2_col2,#T_1e959_row3_col3,#T_1e959_row4_col4,#T_1e959_row5_col5,#T_1e959_row6_col6,#T_1e959_row7_col7,#T_1e959_row8_col8,#T_1e959_row9_col9,#T_1e959_row10_col10,#T_1e959_row11_col11,#T_1e959_row12_col12,#T_1e959_row13_col13,#T_1e959_row14_col14,#T_1e959_row15_col15,#T_1e959_row16_col16,#T_1e959_row17_col17,#T_1e959_row18_col18,#T_1e959_row19_col19,#T_1e959_row20_col20,#T_1e959_row21_col21,#T_1e959_row22_col22,#T_1e959_row23_col23,#T_1e959_row24_col24{
#             background:  gray;
#         }#T_1e959_row1_col3,#T_1e959_row1_col18,#T_1e959_row2_col24,#T_1e959_row3_col1,#T_1e959_row3_col18,#T_1e959_row3_col20,#T_1e959_row3_col21,#T_1e959_row4_col7,#T_1e959_row4_col10,#T_1e959_row4_col13,#T_1e959_row5_col14,#T_1e959_row6_col15,#T_1e959_row7_col4,#T_1e959_row7_col10,#T_1e959_row7_col13,#T_1e959_row8_col9,#T_1e959_row9_col8,#T_1e959_row10_col4,#T_1e959_row10_col7,#T_1e959_row10_col13,#T_1e959_row11_col12,#T_1e959_row12_col11,#T_1e959_row13_col4,#T_1e959_row13_col7,#T_1e959_row13_col10,#T_1e959_row14_col5,#T_1e959_row14_col15,#T_1e959_row15_col6,#T_1e959_row15_col14,#T_1e959_row16_col19,#T_1e959_row17_col18,#T_1e959_row17_col20,#T_1e959_row18_col1,#T_1e959_row18_col3,#T_1e959_row18_col17,#T_1e959_row18_col21,#T_1e959_row19_col16,#T_1e959_row20_col3,#T_1e959_row20_col17,#T_1e959_row20_col21,#T_1e959_row21_col3,#T_1e959_row21_col18,#T_1e959_row21_col20,#T_1e959_row23_col24,#T_1e959_row24_col2,#T_1e959_row24_col23{
#             background:  red;
#         }#T_1e959_row1_col16,#T_1e959_row1_col17,#T_1e959_row1_col19,#T_1e959_row1_col21,#T_1e959_row2_col23,#T_1e959_row3_col17,#T_1e959_row3_col19,#T_1e959_row4_col16,#T_1e959_row5_col6,#T_1e959_row5_col15,#T_1e959_row6_col5,#T_1e959_row6_col14,#T_1e959_row8_col11,#T_1e959_row8_col12,#T_1e959_row9_col11,#T_1e959_row9_col12,#T_1e959_row11_col8,#T_1e959_row11_col9,#T_1e959_row11_col14,#T_1e959_row11_col15,#T_1e959_row12_col8,#T_1e959_row12_col9,#T_1e959_row12_col14,#T_1e959_row12_col15,#T_1e959_row14_col6,#T_1e959_row14_col11,#T_1e959_row14_col12,#T_1e959_row15_col5,#T_1e959_row15_col11,#T_1e959_row15_col12,#T_1e959_row16_col1,#T_1e959_row16_col4,#T_1e959_row17_col1,#T_1e959_row17_col3,#T_1e959_row17_col21,#T_1e959_row18_col20,#T_1e959_row19_col1,#T_1e959_row19_col3,#T_1e959_row20_col18,#T_1e959_row21_col1,#T_1e959_row21_col17,#T_1e959_row23_col2{
#             background:  yellow;
#         }</style><table id="T_1e959_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >goog_trend_score</th>        <th class="col_heading level0 col1" >compound_weighted</th>        <th class="col_heading level0 col2" >neg_weighted</th>        <th class="col_heading level0 col3" >pos_weighted</th>        <th class="col_heading level0 col4" >count_avg7</th>        <th class="col_heading level0 col5" >count_daily_diff</th>        <th class="col_heading level0 col6" >count_weekly_diff</th>        <th class="col_heading level0 col7" >replies_count_avg7</th>        <th class="col_heading level0 col8" >replies_count_daily_diff</th>        <th class="col_heading level0 col9" >replies_count_weekly_diff</th>        <th class="col_heading level0 col10" >retweets_count_avg7</th>        <th class="col_heading level0 col11" >retweets_count_daily_diff</th>        <th class="col_heading level0 col12" >retweets_count_weekly_diff</th>        <th class="col_heading level0 col13" >likes_count_avg7</th>        <th class="col_heading level0 col14" >likes_count_daily_diff</th>        <th class="col_heading level0 col15" >likes_count_weekly_diff</th>        <th class="col_heading level0 col16" >compound_weighted_avg7</th>        <th class="col_heading level0 col17" >compound_weighted_daily_diff</th>        <th class="col_heading level0 col18" >compound_weighted_weekly_diff</th>        <th class="col_heading level0 col19" >pos_weighted_avg7</th>        <th class="col_heading level0 col20" >pos_weighted_daily_diff</th>        <th class="col_heading level0 col21" >pos_weighted_weekly_diff</th>        <th class="col_heading level0 col22" >neg_weighted_avg7</th>        <th class="col_heading level0 col23" >neg_weighted_daily_diff</th>        <th class="col_heading level0 col24" >neg_weighted_weekly_diff</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e959_level0_row0" class="row_heading level0 row0" >goog_trend_score</th>
#                         <td id="T_1e959_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1e959_row0_col1" class="data row0 col1" >-0.041943</td>
#                         <td id="T_1e959_row0_col2" class="data row0 col2" >0.055054</td>
#                         <td id="T_1e959_row0_col3" class="data row0 col3" >0.010403</td>
#                         <td id="T_1e959_row0_col4" class="data row0 col4" >-0.052225</td>
#                         <td id="T_1e959_row0_col5" class="data row0 col5" >-0.039668</td>
#                         <td id="T_1e959_row0_col6" class="data row0 col6" >0.045811</td>
#                         <td id="T_1e959_row0_col7" class="data row0 col7" >-0.006421</td>
#                         <td id="T_1e959_row0_col8" class="data row0 col8" >0.012692</td>
#                         <td id="T_1e959_row0_col9" class="data row0 col9" >0.022870</td>
#                         <td id="T_1e959_row0_col10" class="data row0 col10" >-0.111865</td>
#                         <td id="T_1e959_row0_col11" class="data row0 col11" >-0.001881</td>
#                         <td id="T_1e959_row0_col12" class="data row0 col12" >-0.004534</td>
#                         <td id="T_1e959_row0_col13" class="data row0 col13" >-0.021241</td>
#                         <td id="T_1e959_row0_col14" class="data row0 col14" >-0.018370</td>
#                         <td id="T_1e959_row0_col15" class="data row0 col15" >0.032418</td>
#                         <td id="T_1e959_row0_col16" class="data row0 col16" >-0.058428</td>
#                         <td id="T_1e959_row0_col17" class="data row0 col17" >-0.006804</td>
#                         <td id="T_1e959_row0_col18" class="data row0 col18" >-0.006155</td>
#                         <td id="T_1e959_row0_col19" class="data row0 col19" >0.011959</td>
#                         <td id="T_1e959_row0_col20" class="data row0 col20" >-0.004110</td>
#                         <td id="T_1e959_row0_col21" class="data row0 col21" >0.005402</td>
#                         <td id="T_1e959_row0_col22" class="data row0 col22" >0.096297</td>
#                         <td id="T_1e959_row0_col23" class="data row0 col23" >0.004030</td>
#                         <td id="T_1e959_row0_col24" class="data row0 col24" >0.010132</td>
#             </tr>
#             <tr>
#                         <th id="T_1e959_level0_row1" class="row_heading level0 row1" >compound_weighted</th>
#                         <td id="T_1e959_row1_col0" class="data row1 col0" >-0.041943</td>
#                         <td id="T_1e959_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1e959_row1_col2" class="data row1 col2" >-0.328813</td>
#                         <td id="T_1e959_row1_col3" class="data row1 col3" >0.797707</td>
#                         <td id="T_1e959_row1_col4" class="data row1 col4" >0.329402</td>
#                         <td id="T_1e959_row1_col5" class="data row1 col5" >0.017838</td>
#                         <td id="T_1e959_row1_col6" class="data row1 col6" >0.034359</td>
#                         <td id="T_1e959_row1_col7" class="data row1 col7" >0.312077</td>
#                         <td id="T_1e959_row1_col8" class="data row1 col8" >0.104524</td>
#                         <td id="T_1e959_row1_col9" class="data row1 col9" >0.156385</td>
#                         <td id="T_1e959_row1_col10" class="data row1 col10" >0.200886</td>
#                         <td id="T_1e959_row1_col11" class="data row1 col11" >0.062327</td>
#                         <td id="T_1e959_row1_col12" class="data row1

# %%
social_label_corr
# Out:
#                           Feature      Corr
# 0          compound_weighted_avg7  0.085825
# 1               pos_weighted_avg7  0.085565
# 2               compound_weighted  0.069644
# 3                    pos_weighted  0.066354
# 4          likes_count_daily_diff  0.061732
# 5         likes_count_weekly_diff  0.060719
# 6      retweets_count_weekly_diff  0.051222
# 7       retweets_count_daily_diff  0.043428
# 8              replies_count_avg7  0.039634
# 9               neg_weighted_avg7  0.038582
# 10                   neg_weighted  0.038193
# 11               goog_trend_score  0.029561
# 12       pos_weighted_weekly_diff  0.029184
# 13   compound_weighted_daily_diff  0.028931
# 14       neg_weighted_weekly_diff  0.021523
# 15        pos_weighted_daily_diff  0.021005
# 16      replies_count_weekly_diff  0.020083
# 17  compound_weighted_weekly_diff  0.019506
# 18               count_daily_diff  0.016360
# 19            retweets_count_avg7  0.013670
# 20                     count_avg7  0.010923
# 21       replies_count_daily_diff  0.009763
# 22              count_weekly_diff  0.009540
# 23        neg_weighted_daily_diff  0.008297
# 24               likes_count_avg7  0.002382

# %%
rf2 = RandomForestClassifier()
rf2.fit(bitcoin[social_features], bitcoin['label'])
importances2 = rf2.feature_importances_.tolist()

importances_df2 = pd.DataFrame(list(zip(social_features, importances2)), columns=["feature", "importance"])
importances_df2.sort_values(by=['importance'], ascending=False)
# Out:
#                           feature  importance
# 22              neg_weighted_avg7    0.047877
# 19              pos_weighted_avg7    0.046708
# 1               compound_weighted    0.045447
# 3                    pos_weighted    0.044054
# 9       replies_count_weekly_diff    0.042574
# 14         likes_count_daily_diff    0.041734
# 20        pos_weighted_daily_diff    0.041717
# 6               count_weekly_diff    0.041443
# 12     retweets_count_weekly_diff    0.041380
# 16         compound_weighted_avg7    0.041081
# 8        replies_count_daily_diff    0.040752
# 21       pos_weighted_weekly_diff    0.040682
# 23        neg_weighted_daily_diff    0.040321
# 15        likes_count_weekly_diff    0.040157
# 18  compound_weighted_weekly_diff    0.039702
# 4                      count_avg7    0.039546
# 0                goog_trend_score    0.038643
# 17   compound_weighted_daily_diff    0.038257
# 11      retweets_count_daily_diff    0.037608
# 7              replies_count_avg7    0.037567
# 10            retweets_count_avg7    0.037117
# 24       neg_weighted_weekly_diff    0.036786
# 13               likes_count_avg7    0.034211
# 5                count_daily_diff    0.033633
# 2                    neg_weighted    0.031003

# %%
features_to_try = ['MACD', 'RSI', 'PROC_3', 'Daily_Change_Perc_SP500', 'Daily_Change_Perc_Gold', \
                   'compound_weighted_avg7', 'likes_count_daily_diff', 'pos_weighted_avg7', 'retweets_count_weekly_diff'\
                  'goog_trend_score']
