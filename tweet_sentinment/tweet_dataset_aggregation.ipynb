# %%
import pandas as pd
import numpy as np

# %%
# This dataset is not included in github and can be found here: 
# https://www.kaggle.com/datasets/fabioturazzi/cryptocurrency-tweets-with-sentiment-analysis
tweets = pd.read_csv("tweets_sentiment.csv")
# Out:
# /Users/davidhackett/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
tweets.dtypes
# Out:
# Unnamed: 0           int64
# id                 float64
# conversation_id    float64
# created_at          object
# date                object
# time                object
# timezone             int64
# user_id            float64
# username            object
# name                object
# place               object
# tweet               object
# language            object
# mentions            object
# urls                object
# photos              object
# replies_count        int64
# retweets_count       int64
# likes_count          int64
# hashtags            object
# cashtags            object
# link                object
# retweet               bool
# quote_url           object
# video                int64
# thumbnail           object
# near               float64
# geo                float64
# source             float64
# user_rt_id         float64
# user_rt            float64
# retweet_id         float64
# reply_to            object
# retweet_date       float64
# translate          float64
# trans_src          float64
# trans_dest         float64
# search              object
# decoded_tweet       object
# neg                float64
# neu                float64
# pos                float64
# compound           float64
# dtype: object

# %%
# eliminate unnecessary fields
tweets_filtered = tweets[['date', 'mentions', 'replies_count', 'retweets_count', 'likes_count', \
                          'hashtags', 'cashtags', 'neg', 'neu', 'pos', 'compound']]

# %%
tweets_filtered.sample(10)
# Out:
#               date                                           mentions  \
# 154540  2021-01-14                                                 []
# 679661  2019-08-27  [{'screen_name': 'molochdao', 'name': '👹 moloc...
# 576752  2020-08-27                                                 []
# 16285   2017-12-08                                                 []
# 780243  2018-10-10                                                 []
# 806013  2020-03-01                                                 []
# 79671   2018-10-18                                                 []
# 160052  2021-02-08                                                 []
# 155574  2021-01-20  [{'screen_name': 'farm_tron', 'name': 'tronfar...
# 487155  2019-03-29                                                 []
#
#         replies_count  retweets_count  likes_count  \
# 154540              1               1           33
# 679661              1               5           17
# 576752              2               0           25
# 16285               6              39           38
# 780243              4              11           37
# 806013              2               1           13
# 79671               5              25          111
# 160052              2              10          110
# 155574             22              28           56
# 487155              3               0           18
#
#                                                  hashtags  \
# 154540                                                 []
# 679661                                       ['ethereum']
# 576752                                                 []
# 16285                                                  []
# 780243  ['dapsfam', 'daps', 'bitcoin', 'bit', 'cryptoc...
# 806013                          ['xrp', 'xrpthestandard']
# 79671                                                  []
# 160052                                                 []
# 155574  ['defi', 'tron', 'trx', 'yieldfarming', 'passi...
# 487155                                                 []
#
#                                                  cashtags    neg    neu  \
# 154540                                                 []  0.000  0.887
# 679661                                                 []  0.000  0.905
# 576752                                                 []  0.085  0.915
# 16285                                                  []  0.060  0.940
# 780243  ['daps', 'btc', 'eth', 'xtl', 'xhv', 'vet', 'h...  0.000  1.000
# 806013                                                 []  0.000  0.724
# 79671                                                  []  0.178  0.735
# 160052                                                 []  0.000  1.000
# 155574                                            ['trx']  0.000  0.874
# 487155                                            ['btc']  0.000  0.816
#
#           pos  compound
# 154540  0.113    0.5106
# 679661  0.095    0.5267
# 576752  0.000   -0.3400
# 16285   0.000   -0.1511
# 780243  0.000    0.0000
# 806013  0.276    0.9353
# 79671   0.087   -0.7461
# 160052  0.000    0.0000
# 155574  0.126    0.5574
# 487155  0.184    0.8176

# %%
len(tweets_filtered)
# Out:
# 824908

# %%
bitcoin_tweets = tweets_filtered[tweets_filtered["hashtags"].str.contains("bitcoin|btc", regex=True)]

# %%
len(bitcoin_tweets)
# Out:
# 294562

# %%
bitcoin_tweets.head()
# Out:
#           date                                           mentions  \
# 2   2013-04-14                                                 []
# 24  2014-01-02  [{'screen_name': 'kanyewest', 'name': 'ye', 'i...
# 59  2014-02-05  [{'screen_name': 'brianeha', 'name': 'brian pa...
# 66  2014-02-15                                                 []
# 75  2014-02-25  [{'screen_name': 'fart', 'name': 'food truck d...
#
#     replies_count  retweets_count  likes_count                       hashtags  \
# 2              15             153           61                    ['bitcoin']
# 24             12              76           44                    ['bitcoin']
# 59              4              38           24                    ['bitcoin']
# 66              2              26           23        ['dogecoin', 'bitcoin']
# 75              5              34           38  ['bitcoin', 'cryptocurrency']
#
#    cashtags    neg    neu    pos  compound
# 2        []  0.000  1.000  0.000    0.0000
# 24       []  0.000  1.000  0.000    0.0000
# 59       []  0.000  1.000  0.000    0.0000
# 66       []  0.121  0.879  0.000   -0.2960
# 75       []  0.176  0.707  0.116   -0.2942

# %%
bitcoin_tweets["compound_times_retweets"] = bitcoin_tweets["compound"] * bitcoin_tweets["retweets_count"]
bitcoin_tweets["pos_times_retweets"] = bitcoin_tweets["pos"] * bitcoin_tweets["retweets_count"]
bitcoin_tweets["neg_times_retweets"] = bitcoin_tweets["neg"] * bitcoin_tweets["retweets_count"]
# Out:
# <ipython-input-14-9120c355358a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_tweets["compound_times_retweets"] = bitcoin_tweets["compound"] * bitcoin_tweets["retweets_count"]
# <ipython-input-14-9120c355358a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_tweets["pos_times_retweets"] = bitcoin_tweets["pos"] * bitcoin_tweets["retweets_count"]
# <ipython-input-14-9120c355358a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bitcoin_tweets["neg_times_retweets"] = bitcoin_tweets["neg"] * bitcoin_tweets["retweets_count"]

# %%
bitcoin_tweets.head()
# Out:
#           date                                           mentions  \
# 2   2013-04-14                                                 []
# 24  2014-01-02  [{'screen_name': 'kanyewest', 'name': 'ye', 'i...
# 59  2014-02-05  [{'screen_name': 'brianeha', 'name': 'brian pa...
# 66  2014-02-15                                                 []
# 75  2014-02-25  [{'screen_name': 'fart', 'name': 'food truck d...
#
#     replies_count  retweets_count  likes_count                       hashtags  \
# 2              15             153           61                    ['bitcoin']
# 24             12              76           44                    ['bitcoin']
# 59              4              38           24                    ['bitcoin']
# 66              2              26           23        ['dogecoin', 'bitcoin']
# 75              5              34           38  ['bitcoin', 'cryptocurrency']
#
#    cashtags    neg    neu    pos  compound  compound_times_retweets  \
# 2        []  0.000  1.000  0.000    0.0000                   0.0000
# 24       []  0.000  1.000  0.000    0.0000                   0.0000
# 59       []  0.000  1.000  0.000    0.0000                   0.0000
# 66       []  0.121  0.879  0.000   -0.2960                  -7.6960
# 75       []  0.176  0.707  0.116   -0.2942                 -10.0028
#
#     pos_times_retweets  neg_times_retweets
# 2                0.000               0.000
# 24               0.000               0.000
# 59               0.000               0.000
# 66               0.000               3.146
# 75               3.944               5.984

# %%
bitcoin_pivot = bitcoin_tweets.pivot_table(index="date", \
                                           values=["cashtags", "replies_count", "retweets_count",\
                                                   "likes_count", "neg", "neu", "pos", "compound", \
                                                  "compound_times_retweets","pos_times_retweets", \
                                                   "neg_times_retweets"],
                                          aggfunc={"cashtags" : "count", "replies_count" : np.sum,\
                                                   "retweets_count": np.sum, "likes_count": np.sum,\
                                                   "neg": np.mean, "neu": np.mean, "pos": np.mean,\
                                                   "compound": np.mean,  "compound_times_retweets": np.sum,\
                                                   "pos_times_retweets": np.sum, "neg_times_retweets": np.sum})

# %%
bitcoin_pivot.rename(columns={'cashtags': "count"}, inplace=True)
bitcoin_pivot["pos_weighted"] = bitcoin_pivot["pos_times_retweets"] / bitcoin_pivot['retweets_count']
bitcoin_pivot["neg_weighted"] = bitcoin_pivot["neg_times_retweets"] / bitcoin_pivot['retweets_count']
bitcoin_pivot["compound_weighted"] = bitcoin_pivot["compound_times_retweets"] / bitcoin_pivot['retweets_count']

# %%
bitcoin_pivot.sample(10)
# Out:
#             count  compound  compound_times_retweets  likes_count       neg  \
# date
# 2014-04-07      4  0.199175                  15.6385           80  0.019500
# 2021-01-28    429  0.178076                2694.3217        91055  0.042939
# 2018-02-08    294  0.329200                8006.6888        33872  0.026156
# 2018-08-25    184  0.282227                1652.2869        14032  0.040158
# 2019-04-17    155  0.352056                1588.3726         9719  0.015516
# 2017-12-16    255  0.260017                6659.2862        23598  0.032741
# 2020-01-16    125  0.388348                2204.5231         8833  0.036072
# 2017-05-21     91  0.176452                1410.8219         4175  0.010879
# 2018-09-26    192  0.364990                2620.1859        11627  0.024177
# 2016-04-20      9  0.084711                   2.4481          255  0.038889
#
#             neg_times_retweets       neu       pos  pos_times_retweets  \
# date
# 2014-04-07               2.028  0.894750  0.085750               7.557
# 2021-01-28             590.962  0.862911  0.094149            1407.886
# 2018-02-08             405.459  0.863629  0.110207            2343.750
# 2018-08-25             218.235  0.852098  0.107739             590.524
# 2019-04-17              43.230  0.883729  0.100761             489.994
# 2017-12-16             235.530  0.868867  0.098357            1901.054
# 2020-01-16             148.364  0.840712  0.123200             653.781
# 2017-05-21              23.817  0.905604  0.083549             651.963
# 2018-09-26              86.259  0.872755  0.103089             625.814
# 2016-04-20              12.600  0.867889  0.093222              17.509
#
#             replies_count  retweets_count  pos_weighted  neg_weighted  \
# date
# 2014-04-07              6             104      0.072663      0.019500
# 2021-01-28           6689           17793      0.079126      0.033213
# 2018-02-08           6442           23710      0.098851      0.017101
# 2018-08-25           1713            5978      0.098783      0.036506
# 2019-04-17            827            4839      0.101259      0.008934
# 2017-12-16           2550           13815      0.137608      0.017049
# 2020-01-16           3626            3745      0.174574      0.039617
# 2017-05-21            151            5101      0.127811      0.004669
# 2018-09-26           1518            6093      0.102710      0.014157
# 2016-04-20             15             255      0.068663      0.049412
#
#             compound_weighted
# date
# 2014-04-07           0.150370
# 2021-01-28           0.151426
# 2018-02-08           0.337692
# 2018-08-25           0.276395
# 2019-04-17           0.328244
# 2017-12-16           0.482033
# 2020-01-16           0.588658
# 2017-05-21           0.276578
# 2018-09-26           0.430032
# 2016-04-20           0.009600

# %%
rolling_avg_col = ['count', 'replies_count', 'retweets_count', 'likes_count', 'compound_weighted', 'pos_weighted', 'neg_weighted']

# %%
for col in rolling_avg_col:
    bitcoin_pivot[f"{col}_avg7"] = bitcoin_pivot[col].rolling(7).mean()
    bitcoin_pivot[f'{col}_daily_diff'] = bitcoin_pivot[col] - bitcoin_pivot[col].shift(1)
    bitcoin_pivot[f'{col}_weekly_diff'] = bitcoin_pivot[col] - bitcoin_pivot[f"{col}_avg7"]

# %%
bitcoin_pivot.head(10)
# Out:
#             count  compound  compound_times_retweets  likes_count    neg  \
# date
# 2013-02-26      1   0.23820                  26.2020           32  0.000
# 2013-04-14      3   0.00000                   0.0000          183  0.000
# 2013-06-04      1   0.42150                  27.8190           27  0.000
# 2013-06-30      1   0.61660                 123.3200           62  0.000
# 2013-08-11      1  -0.07720                  -9.6500           17  0.071
# 2013-10-09      1   0.00000                   0.0000           23  0.000
# 2013-10-18      1   0.67920                  34.6392           30  0.000
# 2013-11-12      1   0.00000                   0.0000           20  0.000
# 2013-11-24      2  -0.12825                  35.5430          101  0.100
# 2014-01-02      2   0.00000                   0.0000           88  0.000
#
#             neg_times_retweets     neu     pos  pos_times_retweets  \
# date
# 2013-02-26               0.000  0.9020  0.0980              10.780
# 2013-04-14               0.000  1.0000  0.0000               0.000
# 2013-06-04               0.000  0.8230  0.1770              11.682
# 2013-06-30               0.000  0.8080  0.1920              38.400
# 2013-08-11               8.875  0.9290  0.0000               0.000
# 2013-10-09               0.000  1.0000  0.0000               0.000
# 2013-10-18               0.000  0.7080  0.2920              14.892
# 2013-11-12               0.000  1.0000  0.0000               0.000
# 2013-11-24               6.200  0.8295  0.0705              34.686
# 2014-01-02               0.000  1.0000  0.0000               0.000
#
#             replies_count  ...  likes_count_weekly_diff  \
# date                       ...
# 2013-02-26              2  ...                      NaN
# 2013-04-14             45  ...                      NaN
# 2013-06-04              8  ...                      NaN
# 2013-06-30              0  ...                      NaN
# 2013-08-11              2  ...                      NaN
# 2013-10-09              6  ...                      NaN
# 2013-10-18              2  ...               -23.428571
# 2013-11-12              3  ...               -31.714286
# 2013-11-24             24  ...                61.000000
# 2014-01-02             24  ...                39.285714
#
#             compound_weighted_avg7  compound_weighted_daily_diff  \
# date
# 2013-02-26                     NaN                           NaN
# 2013-04-14                     NaN                     -0.238200
# 2013-06-04                     NaN                      0.421500
# 2013-06-30                     NaN                      0.195100
# 2013-08-11                     NaN                     -0.693800
# 2013-10-09                     NaN                      0.077200
# 2013-10-18                0.268329                      0.679200
# 2013-11-12                0.234300                     -0.679200
# 2013-11-24                0.252631                      0.128314
# 2014-01-02                0.192416                     -0.128314
#
#             compound_weighted_weekly_diff  pos_weighted_avg7  \
# date
# 2013-02-26                            NaN                NaN
# 2013-04-14                            NaN                NaN
# 2013-06-04                            NaN                NaN
# 2013-06-30                            NaN                NaN
# 2013-08-11                            NaN                NaN
# 2013-10-09                            NaN                NaN
# 2013-10-18                       0.410871           0.108429
# 2013-11-12                      -0.234300           0.094429
# 2013-11-24                      -0.124317           0.112317
# 2014-01-02                      -0.192416           0.087031
#
#             pos_weighted_daily_diff  pos_weighted_weekly_diff  \
# date
# 2013-02-26                      NaN                       NaN
# 2013-04-14                 -0.09800                       NaN
# 2013-06-04                  0.17700                       NaN
# 2013-06-30                  0.01500                       NaN
# 2013-08-11                 -0.19200                       NaN
# 2013-10-09                  0.00000                       NaN
# 2013-10-18                  0.29200                  0.183571
# 2013-11-12                 -0.29200                 -0.094429
# 2013-11-24                  0.12522                  0.012903
# 2014-01-02                 -0.12522                 -0.087031
#
#             neg_weighted_avg7  neg_weighted_daily_diff  \
# date
# 2013-02-26                NaN                      NaN
# 2013-04-14                NaN                 0.000000
# 2013-06-04                NaN                 0.000000
# 2013-06-30                NaN                 0.000000
# 2013-08-11                NaN                 0.071000
# 2013-10-09                NaN                -0.071000
# 2013-10-18           0.010143                 0.000000
# 2013-11-12           0.010143                 0.000000
# 2013-11-24           0.013340                 0.022383
# 2014-01-02           0.013340                -0.022383
#
#             neg_weighted_weekly_diff
# date
# 2013-02-26                       NaN
# 2013-04-14                       NaN
# 2013-06-04                       NaN
# 2013-06-30                       NaN
# 2013-08-11                       NaN
# 2013-10-09                       NaN
# 2013-10-18                 -0.010143
# 2013-11-12                 -0.010143
# 2013-11-24                  0.009042
# 2014-01-02                 -0.013340
#
# [10 rows x 35 columns]

# %%
bitcoin_pivot.to_csv("../data/bitcoin_daily_tweets.csv")
